# %%
datasets = [

    {
        'filename': 'orders'
    },
    {
        'filename' : 'customers'
    },
    {
        'filename' : 'products'
    }

]

# %%
dbutils.jobs.taskValues.set('output_datset',datasets)
